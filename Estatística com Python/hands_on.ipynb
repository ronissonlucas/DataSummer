# %% [markdown]
# # <b>Hands on!<b/>

# %% [markdown]
# # 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

np.random.seed(20)
n = 2_000  #size
data = {
    'A': np.random.normal(loc = 100, scale = 1, size = n),
    'B': np.random.normal(loc = 100, scale = 2, size = n),
    'C': np.random.normal(loc = 100, scale = 5, size = n),
    'D': np.random.lognormal(mean = 2, sigma = 1.1, size = n),
    'E': np.random.lognormal(mean = 2, sigma = 1.2, size = n),
    'F': np.random.lognormal(mean = 2, sigma = 1.3, size = n),
    'G': np.random.randn(n),
    'H': np.random.binomial(n = 10, p = 0.8, size = n)
}

df = pd.DataFrame(data)

# %%
sns.kdeplot(x = 'A', data = df)
sns.kdeplot(x = 'B', data = df)
sns.kdeplot(x = 'C', data = df)
plt.title('Distributions')
plt.legend(['A', 'B', 'C'], loc = 'upper left')
plt.xlabel('Values')
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

# %%
sns.kdeplot(x = 'A', data = df)

# %%
serie = pd.Series(np.random.normal(100, 1, 100))
serie.plot()

# %%
serie.plot(kind = 'kde')

# %%
serie.plot(kind = 'hist', bins = 20)

# %%
serie = pd.Series(np.random.normal(100, 5, 100))
serie.plot()

# %%
serie.plot(kind = 'kde')

# %%
serie = pd.Series(np.random.normal(100, 0.5, 100))
serie.plot()

# %%
serie.plot(kind = 'kde')

# %% [markdown]
# # 2

# %%
sns.kdeplot(x = 'D', data = df)
sns.kdeplot(x = 'E', data = df)
sns.kdeplot(x = 'F', data = df)
plt.title('Distributions')
plt.xlabel('Values')
plt.legend(['D', 'E', 'F'], loc = 'upper right')
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

# %% [markdown]
# # 3

# %%
sns.jointplot(x = 'A', y = 'B', data = df);

# %%
sns.jointplot(x = 'D', y = 'F', data = df);

# %% [markdown]
# # 4

# %%
for coluna,valores in df.iteritems():
    print(coluna)
    print(valores)
    print()
# Out:
# A
# 0       100.883893
# 1       100.195865
# 2       100.357537
# 3        97.656738
# 4        98.915167
#            ...
# 1995     98.368090
# 1996     99.685726
# 1997     99.791299
# 1998     99.913642
# 1999     98.945688
# Name: A, Length: 2000, dtype: float64
#
# B
# 0       102.445802
# 1        99.007382
# 2        96.341847
# 3       100.241640
# 4       100.602171
#            ...
# 1995     99.209502
# 1996    101.621461
# 1997    101.055357
# 1998    100.184512
# 1999    101.378790
# Name: B, Length: 2000, dtype: float64
#
# C
# 0       105.389348
# 1       106.483443
# 2        96.661463
# 3       106.762574
# 4        97.836077
#            ...
# 1995     97.769527
# 1996     98.977508
# 1997     94.796605
# 1998     96.975738
# 1999     94.494638
# Name: C, Length: 2000, dtype: float64
#
# D
# 0        4.301081
# 1        2.039321
# 2        3.010788
# 3       10.485774
# 4       23.349188
#           ...
# 1995     7.263969
# 1996     2.697143
# 1997     6.469235
# 1998     3.035740
# 1999     2.905492
# Name: D, Length: 2000, dtype: float64
#
# E
# 0        1.588100
# 1        1.486563
# 2        3.249671
# 3       29.973364
# 4        1.070186
#           ...
# 1995     2.159312
# 1996    27.079392
# 1997     2.724241
# 1998     1.388178
# 1999     2.062246
# Name: E, Length: 2000, dtype: float64
#
# F
# 0        5.090603
# 1        6.697147
# 2        9.179327
# 3        3.502739
# 4       25.273968
#           ...
# 1995    24.150155
# 1996     5.438890
# 1997    57.849436
# 1998     6.296632
# 1999     6.099685
# Name: F, Length: 2000, dtype: float64
#
# G
# 0      -0.257072
# 1       2.078837
# 2      -1.513925
# 3      -0.817592
# 4       0.543835
#           ...
# 1995    1.866827
# 1996   -1.281635
# 1997    0.055087
# 1998    0.746932
# 1999    1.818866
# Name: G, Length: 2000, dtype: float64
#
# H
# 0        8
# 1       10
# 2        8
# 3        7
# 4        9
#         ..
# 1995     8
# 1996     8
# 1997     8
# 1998     9
# 1999     9
# Name: H, Length: 2000, dtype: int64

# %%
for chave in data:
    print(chave)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H

# %%
for coluna in df:
    print(coluna)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
for coluna in df.columns:
    print(coluna)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H

# %%
for column in data:
    sns.histplot(x = column, data = df, kde = True)
    plt.title(column+' - histogram')
    plt.show()

# %% [markdown]
# # 5

# %%
sns.violinplot(y = 'G', data = df)
plt.title('G - violin plot');

# %%
sns.violinplot(y = 'H', data = df)
plt.title('H - violin plot');

# %%
sns.kdeplot(y = 'H', data = df)
plt.title('H - violin plot');

# %%
sns.boxplot(y = 'H', data =df)

# %% [markdown]
# # 6

# %%
import pandas as pd
from numpy import random
data = random.normal(loc = 10, scale = 3, size = (20, 5))
df = pd.DataFrame(data, columns = list('ABCDE'), index = range(1, data.shape[0]+1))
df
# Out:
#             A          B          C          D          E
# 1    9.010290  11.924963  11.132314   8.842637  14.347309
# 2   11.972933  11.899876  11.484853  11.314979  14.583305
# 3    7.571712  11.996382  14.163680  16.141832  13.742164
# 4   11.073263  12.417143   7.736254   5.688257   8.956058
# 5    3.143993   9.963414   8.493611   8.619952  12.009723
# 6    5.297335  10.235258  13.967883  13.864433   8.483064
# 7   14.126710  10.636354   9.850621   7.511202   5.821121
# 8    9.734788   6.269045   9.955327   7.190388   9.677248
# 9    8.993539   8.273334  15.069280  12.709876  11.106433
# 10   9.254605   9.546389  14.369259  11.387553   8.858337
# 11   7.737481  11.619141  11.227933   9.902308  12.901962
# 12   3.988519  15.024170   8.608670  10.221006  11.123844
# 13   2.910386  12.462069  12.846636   9.880161  13.017338
# 14   9.839917  14.857468   8.662757   4.792510  12.027677
# 15   8.087771   6.849994  14.161271   6.951995   8.542216
# 16  10.325431  11.074313  11.543259  13.188932   4.987696
# 17   8.995345  11.500810   7.030509  12.006984   9.613678
# 18   6.961303   8.800609   5.462987  11.210294   9.296100
# 19  14.194859   3.265153   8.462883   5.442395  10.410896
# 20  11.802322   8.892195  12.629389   8.069590  11.273626

# %% [markdown]
# # 7

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random

# %%
data = random.normal(size = 3000)

# %%
sns.displot(data, kind = 'kde')
plt.show()

# %%
sns.displot(data, kind = 'hist')
plt.show()
